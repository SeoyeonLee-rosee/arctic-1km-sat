# %%
import pandas as pd
import csv

import numpy as np
import numpy.ma as ma
import time
from  datetime import date,timedelta
from dateutil.relativedelta import relativedelta
import statsmodels.api as sm

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.cm as cm
import matplotlib.path as mpath
from matplotlib.colors import ListedColormap

from scipy.optimize import curve_fit
import pandas as pd
#import nctoolkit as nc
import xarray as xr

import seaborn as sns

# %%
dirpath = '../data/constraint/'
wt = 3.
da = pd.read_csv(dirpath+"constraint.csv")
da

# %%
hfont = {'fontname':'Arial'}
sample_size = 50
color_num = 50
C = np.arange(0,color_num)

xmin = -3
xmax = 3
ymin = -30
ymax = -10

dat= da[(da["Area"]=='N.H.') & (da["Month"]=='Winter')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
wt = 1
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

wt = 2
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-3,-2,-1,0,1,2,3], fontsize=15, **hfont)
plt.yticks([-30,-25,-20,-15,-10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.H._Winter_shad.png', dpi=300, trnsparent=True)
plt.savefig(dirpath+'FIG/const_N.H._Winter_shad.eps', trnsparent=True)



dat= da[(da["Area"]=='EA') & (da["Month"]=='Winter')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
wt = 1
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

wt = 2
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)
        
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-3,-2,-1,0,1,2,3], fontsize=15, **hfont)
plt.yticks([-30,-25,-20,-15,-10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_EA_Winter_shad.png', dpi=300, trnsparent=True)
plt.savefig(dirpath+'FIG/const_EA_Winter_shad.eps', trnsparent=True)



dat= da[(da["Area"]=='N.A.') & (da["Month"]=='Winter')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
wt = 1
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

wt = 2
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-3,-2,-1,0,1,2,3], fontsize=15, **hfont)
plt.yticks([-30,-25,-20,-15,-10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.A._Winter_shad.png', dpi=300, trnsparent=True)
plt.savefig(dirpath+'FIG/const_N.A._Winter_shad.eps', trnsparent=True)




xmin = -1
xmax = 2
ymin = -5
ymax = 10

dat= da[(da["Area"]=='N.H.') & (da["Month"]=='Summer')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
wt = 1
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

wt = 2
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-1,0,1,2], fontsize=15, **hfont)
plt.yticks([-5,0,5,10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.H._Summer_shad.png')
plt.savefig(dirpath+'FIG/const_N.H._Summer_shad.eps')




dat= da[(da["Area"]=='EA') & (da["Month"]=='Summer')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
wt = 1
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

wt = 2
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-1,0,1,2], fontsize=15, **hfont)
plt.yticks([-5,0,5,10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_EA_Summer_shad.png')
plt.savefig(dirpath+'FIG/const_EA_Summer_shad.eps')



dat= da[(da["Area"]=='N.A.') & (da["Month"]=='Summer')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
wt = 1
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

wt = 2
x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-1,0,1,2], fontsize=15, **hfont)
plt.yticks([-5,0,5,10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.A._Summer_shad.png')
plt.savefig(dirpath+'FIG/const_N.A._Summer_shad.eps')

# %%
hfont = {'fontname':'Arial'}
sample_size = 50
color_num = 50
C = np.arange(0,color_num)

wt = 1
xmin = -3
xmax = 3
ymin = -30
ymax = -10

dat= da[(da["Area"]=='N.H.') & (da["Month"]=='Winter')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-3,-2,-1,0,1,2,3], fontsize=15, **hfont)
plt.yticks([-30,-25,-20,-15,-10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.H._Winter_cir.png', dpi=300, trnsparent=True)
plt.savefig(dirpath+'FIG/const_N.H._Winter_cir.eps', trnsparent=True)



dat= da[(da["Area"]=='EA') & (da["Month"]=='Winter')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-3,-2,-1,0,1,2,3], fontsize=15, **hfont)
plt.yticks([-30,-25,-20,-15,-10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_EA_Winter_cir.png', dpi=300, trnsparent=True)
plt.savefig(dirpath+'FIG/const_EA_Winter_cir.eps', trnsparent=True)



dat= da[(da["Area"]=='N.A.') & (da["Month"]=='Winter')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-3,-2,-1,0,1,2,3], fontsize=15, **hfont)
plt.yticks([-30,-25,-20,-15,-10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.A._Winter_cir.png', dpi=300, trnsparent=True)
plt.savefig(dirpath+'FIG/const_N.A._Winter_cir.eps', trnsparent=True)




xmin = -1
xmax = 2
ymin = -5
ymax = 10

dat= da[(da["Area"]=='N.H.') & (da["Month"]=='Summer')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-1,0,1,2], fontsize=15, **hfont)
plt.yticks([-5,0,5,10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.H._Summer_cir.png')
plt.savefig(dirpath+'FIG/const_N.H._Summer_cir.eps')




dat= da[(da["Area"]=='EA') & (da["Month"]=='Summer')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-1,0,1,2], fontsize=15, **hfont)
plt.yticks([-5,0,5,10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_EA_Summer_cir.png')
plt.savefig(dirpath+'FIG/const_EA_Summer_cir.eps')



dat= da[(da["Area"]=='N.A.') & (da["Month"]=='Summer')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-1,0,1,2], fontsize=15, **hfont)
plt.yticks([-5,0,5,10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.A._Summer_cir.png')
plt.savefig(dirpath+'FIG/const_N.A._Summer_cir.eps')

# %%
hfont = {'fontname':'Arial'}
sample_size = 50
color_num = 50
C = np.arange(0,color_num)

xmin = -3
xmax = 3
ymin = -30
ymax = -10

dat= da[(da["Area"]=='N.H.') & (da["Month"]=='Winter')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
#wt = 1
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
#plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
#plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
#plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
#plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

#wt = 2
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

for x,y,z in zip(dat["Trend"],dat["Mean"],dat["Name"]):
    label = str(z)
    if label != str('MODIS'):
        ax1=plt.annotate(label, # 출력할 텍스트, 여기에선 y좌표
                    (x,y), # 텍스트를 출력할 좌표
                    textcoords="offset points", # 텍스트 위치를 (x,y)로 부터의 오프셋 (offset_x, offset_y)로 지정
                    xytext=(0, -3.8), # (x, y)로 부터의 오프셋 (offset_x, offset_y), 여기에선 y 좌표로 +20 이동합니다.
                    ha='center', fontsize=10, **hfont) # 수평방향으로 중앙정렬합니다.

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-3,-2,-1,0,1,2,3], fontsize=15, **hfont)
plt.yticks([-30,-25,-20,-15,-10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.H._Winter_num.png', dpi=300, trnsparent=True)
plt.savefig(dirpath+'FIG/const_N.H._Winter_num.eps', trnsparent=True)



dat= da[(da["Area"]=='EA') & (da["Month"]=='Winter')]
fig = plt.figure(figsize=(10,7))
#ax1 = sns.lmplot(data = dat, x = "Trend", y="Mean", size=8, hue = "Kind", legend=False)
#ax1=plt.scatter(dat["Trend"],dat["Mean"], s=250, alpha=0.5)
xx=dat["Trend"]
yy=dat["Mean"]
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
#wt = 1
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
#plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
#plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
#plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
#plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

#wt = 2
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

for x,y,z in zip(dat["Trend"],dat["Mean"],dat["Name"]):
    label = str(z)
    if label != str('MODIS'):
        ax1=plt.annotate(label, # 출력할 텍스트, 여기에선 y좌표
                    (x,y), # 텍스트를 출력할 좌표
                    textcoords="offset points", # 텍스트 위치를 (x,y)로 부터의 오프셋 (offset_x, offset_y)로 지정
                    xytext=(0, -3.8), # (x, y)로 부터의 오프셋 (offset_x, offset_y), 여기에선 y 좌표로 +20 이동합니다.
                    ha='center', fontsize=10, **hfont) # 수평방향으로 중앙정렬합니다.
        
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-3,-2,-1,0,1,2,3], fontsize=15, **hfont)
plt.yticks([-30,-25,-20,-15,-10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_EA_Winter_num.png', dpi=300, trnsparent=True)
plt.savefig(dirpath+'FIG/const_EA_Winter_num.eps', trnsparent=True)



dat= da[(da["Area"]=='N.A.') & (da["Month"]=='Winter')]
fig = plt.figure(figsize=(10,7))
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
#wt = 1
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
#plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
#plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
#plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
#plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

#wt = 2
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

for x,y,z in zip(dat["Trend"],dat["Mean"],dat["Name"]):
    label = str(z)
    if label != str('MODIS'):
        ax1=plt.annotate(label, # 출력할 텍스트, 여기에선 y좌표
                    (x,y), # 텍스트를 출력할 좌표
                    textcoords="offset points", # 텍스트 위치를 (x,y)로 부터의 오프셋 (offset_x, offset_y)로 지정
                    xytext=(0, -3.8), # (x, y)로 부터의 오프셋 (offset_x, offset_y), 여기에선 y 좌표로 +20 이동합니다.
                    ha='center', fontsize=10, **hfont) # 수평방향으로 중앙정렬합니다.
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-3,-2,-1,0,1,2,3], fontsize=15, **hfont)
plt.yticks([-30,-25,-20,-15,-10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.A._Winter_num.png', dpi=300, trnsparent=True)
plt.savefig(dirpath+'FIG/const_N.A._Winter_num.eps', trnsparent=True)




xmin = -1
xmax = 2
ymin = -5
ymax = 10

dat= da[(da["Area"]=='N.H.') & (da["Month"]=='Summer')]
fig = plt.figure(figsize=(10,7))
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
#wt = 1
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
#plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
#plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
#plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
#plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

#wt = 2
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

for x,y,z in zip(dat["Trend"],dat["Mean"],dat["Name"]):
    label = str(z)
    if label != str('MODIS'):
        ax1=plt.annotate(label, # 출력할 텍스트, 여기에선 y좌표
                    (x,y), # 텍스트를 출력할 좌표
                    textcoords="offset points", # 텍스트 위치를 (x,y)로 부터의 오프셋 (offset_x, offset_y)로 지정
                    xytext=(0, -3.8), # (x, y)로 부터의 오프셋 (offset_x, offset_y), 여기에선 y 좌표로 +20 이동합니다.
                    ha='center', fontsize=10, **hfont) # 수평방향으로 중앙정렬합니다.
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-1,0,1,2], fontsize=15, **hfont)
plt.yticks([-5,0,5,10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.H._Summer_num.png')
plt.savefig(dirpath+'FIG/const_N.H._Summer_num.eps')




dat= da[(da["Area"]=='EA') & (da["Month"]=='Summer')]
fig = plt.figure(figsize=(10,7))
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
#wt = 1
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
#plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
#plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
#plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
#plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

#wt = 2
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

for x,y,z in zip(dat["Trend"],dat["Mean"],dat["Name"]):
    label = str(z)
    if label != str('MODIS'):
        ax1=plt.annotate(label, # 출력할 텍스트, 여기에선 y좌표
                    (x,y), # 텍스트를 출력할 좌표
                    textcoords="offset points", # 텍스트 위치를 (x,y)로 부터의 오프셋 (offset_x, offset_y)로 지정
                    xytext=(0, -3.8), # (x, y)로 부터의 오프셋 (offset_x, offset_y), 여기에선 y 좌표로 +20 이동합니다.
                    ha='center', fontsize=10, **hfont) # 수평방향으로 중앙정렬합니다.

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-1,0,1,2], fontsize=15, **hfont)
plt.yticks([-5,0,5,10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_EA_Summer_num.png')
plt.savefig(dirpath+'FIG/const_EA_Summer_num.eps')



dat= da[(da["Area"]=='N.A.') & (da["Month"]=='Summer')]
fig = plt.figure(figsize=(10,7))
#ax1=plt.scatter(xx[1::],yy[1::], s=280, c=C, cmap=plt.cm.get_cmap('rainbow_r', color_num), alpha=0.5)
#wt = 1
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]

#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.plot((xmin,x2), (y1,y1), '--', color='0.7')
#plt.plot((xmin,x2), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,ymax), '--', color='0.7')
#plt.plot((x2,x2), (ymin,ymax), '--', color='0.7')
#plt.plot((xmin,xmax), (y1,y1), '--', color='0.7')
#plt.plot((xmin,xmax), (y2,y2), '--', color='0.7')
#plt.plot((x1,x1), (ymin,y2), '--', color='0.7')
#plt.plot((x2,x2), (ymin,y2), '--', color='0.7')
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

#wt = 2
#x1= dat[dat["Kind"]=="MODIS"]["Trend"]-wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#x2= dat[dat["Kind"]=="MODIS"]["Trend"]+wt*dat[dat["Kind"]=="MODIS"]["T_std"]
#y1= dat[dat["Kind"]=="MODIS"]["Mean"]-wt*dat[dat["Kind"]=="MODIS"]["STD"]
#y2= dat[dat["Kind"]=="MODIS"]["Mean"]+wt*dat[dat["Kind"]=="MODIS"]["STD"]
#plt.fill([x1,x1,x2,x2],[y1,y2,y2,y1], color='C0', alpha=0.2)

for x,y,z in zip(dat["Trend"],dat["Mean"],dat["Name"]):
    label = str(z)
    if label != str('MODIS'):
        ax1=plt.annotate(label, # 출력할 텍스트, 여기에선 y좌표
                    (x,y), # 텍스트를 출력할 좌표
                    textcoords="offset points", # 텍스트 위치를 (x,y)로 부터의 오프셋 (offset_x, offset_y)로 지정
                    xytext=(0, -3.8), # (x, y)로 부터의 오프셋 (offset_x, offset_y), 여기에선 y 좌표로 +20 이동합니다.
                    ha='center', fontsize=10, **hfont) # 수평방향으로 중앙정렬합니다.

plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.xticks([-1,0,1,2], fontsize=15, **hfont)
plt.yticks([-5,0,5,10], fontsize=15, **hfont)
plt.xlabel('Change rate [°C/10-yr]',fontsize=20, **hfont)
plt.ylabel('Mean [°C]',fontsize=20, **hfont)
plt.savefig(dirpath+'FIG/const_N.A._Summer_num.png')
plt.savefig(dirpath+'FIG/const_N.A._Summer_num.eps')
